# %% [markdown]
# <a href="https://colab.research.google.com/github/tejaswinik0707/Tejuuuuu/blob/main/jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=(input("length of string"))
print(a)

a=input("enter first string")
b=input("enter second string")
c= a+b
print(c)

a="Tejaswini"
b="Kawale"
c=a+b
print(c)
